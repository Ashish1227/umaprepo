# %%
import numpy as np
from sklearn.datasets import load_digits
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
sns.set(style='white', context='notebook', rc={'figure.figsize':(14,10)})

# %%
penguins = pd.read_csv("https://raw.githubusercontent.com/allisonhorst/palmerpenguins/c19a904462482430170bfe2c718775ddb7dbb885/inst/extdata/penguins.csv")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex  year
# 0       3750.0    male  2007
# 1       3800.0  female  2007
# 2       3250.0  female  2007
# 3          NaN     NaN  2007
# 4       3450.0  female  2007

# %%
penguins = penguins.dropna()
penguins.species.value_counts()
# Out:
# species
# Adelie       146
# Gentoo       119
# Chinstrap     68
# Name: count, dtype: int64

# %%
sns.pairplot(penguins.drop("year", axis=1), hue='species');

# %%
import umap.umap_ as umap

# %%
reducer = umap.UMAP()

# %%
penguin_data = penguins[
    [
        "bill_length_mm",
        "bill_depth_mm",
        "flipper_length_mm",
        "body_mass_g",
    ]
].values
scaled_penguin_data = StandardScaler().fit_transform(penguin_data)

# %%
scaled_penguin_data[0]
# Out:
# array([-0.89604189,  0.7807321 , -1.42675157, -0.56847478])

# %%
embedding = reducer.fit_transform(scaled_penguin_data)
embedding.shape
# Out:
# (333, 2)

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 4
#       1 plt.scatter(
#       2     embedding[:, 0],
#       3     embedding[:, 1],
# ----> 4     c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1})])
#       5 plt.gca().set_aspect('equal', 'datalim')
#       6 plt.title('UMAP projection of the Penguin dataset', fontsize=24);
#
# Cell In[20], line 4, in <listcomp>(.0)
#       1 plt.scatter(
#       2     embedding[:, 0],
#       3     embedding[:, 1],
# ----> 4     c=[sns.color_palette()[x] for x in penguins.species.map({"Adelie":0, "Chinstrap":1})])
#       5 plt.gca().set_aspect('equal', 'datalim')
#       6 plt.title('UMAP projection of the Penguin dataset', fontsize=24);
#
# TypeError: list indices must be integers or slices, not float
